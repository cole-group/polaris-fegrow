# %% [markdown]
# # FEgrow: An Open-Source Molecular Builder and Free Energy Preparation Workflow
#
# **Authors: Mateusz K Bieniek, Ben Cree, Rachael Pirie, Joshua T. Horton, Natalie J. Tatum, Daniel J. Cole**

# %% [markdown]
# ## Overview
#
# Building and scoring molecules can be further streamlined by employing our established protocol. Here we show how to quickly build a library and score the entire library.

# %%
import pandas as pd
import prody
from rdkit import Chem

import fegrow
from fegrow import ChemSpace

from fegrow.testing import core_5R83_path, rec_5R83_path, data_5R83_path
# Out:
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tmp/ipykernel_955287/1015952767.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %% [markdown]
# # Prepare the ligand template

# %%
#!grep "XEY" 7l10.pdb > in.pdb
# !obabel -ipdb lig-rebuilt.pdb -O in-H.sdf -p 7
# Out:
# 1 molecule converted

# %%
#scaffold = Chem.SDMolSupplier(core_5R83_path)[0]
scaffold = Chem.SDMolSupplier('in-H.sdf')[0]

# %%
toview = fegrow.RMol(scaffold)
toview.rep2D(idx=True, size=(500, 500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %%
with open('smiles-test-MERS.txt') as f:
    mols = f.read().splitlines()

# %%
mols[0]
# Out:
# 'O=C1c2ccc(Cl)cc2[C@@]2(CN1Cc1nnco1)C(=O)N(c1cncc3ccccc13)C[C@@H]2CNc1ncncn1'

# %%
#mols = ['C1(OCCC)=CC=CN=C1',
#        'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2CNc2ccncn2)c2cc(Cl)ccc2C1=O',
#        'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2CNc2cnn(C)c2)c2cc(Cl)ccc2C1=O',
#        'Cc1cnc(CN2C[C@@]3(C(=O)N(c4cncc5ccccc45)C[C@@H]3C)c3cc(F)ccc3C2=O)cn1',
#        'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2COC(C)C)c2cc(Cl)ccc2C1=O',
#        'C[C@H]1CN(c2cncc3ccccc23)C(=O)[C@@]12CN(Cc1nccn1C)C(=O)c1ccc(F)cc12'
#       ]

# %%
Chem.MolFromSmiles(mols[0])

# %%
pattern = scaffold

for i in range(len(mols)):
    mol = Chem.MolFromSmiles(mols[i])
    if mol.HasSubstructMatch(pattern) == False:
        print(i, mols[i])
# Out:
# 78 COC(=O)N[C@H](C(=O)N1C[C@H](C(F)(F)F)C[C@H]1C(=O)N[C@H](C[NH3+])C[C@@H]1CCNC1=O)C(C)(C)C

# %% [markdown]
# As we are using already prepared Smiles that have the scaffold as a substructure, it is not needed to set any growing vector.

# %%
from dask.distributed import LocalCluster
lc = LocalCluster(processes=True, n_workers=None, threads_per_worker=1)
# Out:
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34559 instead
#   warnings.warn(
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# 2025-03-04 16:43:54,440 - distributed.nanny - WARNING - Restarting worker

# %%
# create the chemical space
cs = ChemSpace(dask_cluster=lc)
cs
# Out:
# Failed to patch pandas - unable to change molecule rendering
# Dask can be watched on http://127.0.0.1:34559/status
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Smiles</th>
#       <th>score</th>
#       <th>h</th>
#       <th>Training</th>
#       <th>Success</th>
#       <th>enamine_searched</th>
#       <th>enamine_id</th>
#       <th>2D</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#cs._dask_cluster

# %%
# we're not growing the scaffold, we're superimposing bigger molecules on it
cs.add_scaffold(scaffold)
# Out:
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/fegrow/package.py:799: UserWarning: The template does not have an attachement (Atoms with index 0, or in case of Smiles the * character. )
#   warnings.warn("The template does not have an attachement (Atoms with index 0, "

# %%
# get the protein-ligand complex structure
#!wget -nc https://files.rcsb.org/download/3vf6.pdb

# load the complex with the ligand
sys = prody.parsePDB('complex-MERS.pdb')

# remove any unwanted molecules
rec = sys.select('not (nucleic or hetatm or water)')

# save the processed protein
prody.writePDB('rec.pdb', rec)

# fix the receptor file (missing residues, protonation, etc)
fegrow.fix_receptor("rec.pdb", "rec_final.pdb")

# load back into prody
#rec_final = prody.parsePDB("rec_final.pdb")
#rec_final = prody.parsePDB("out.pdb")

# fix the receptor file (missing residues, protonation, etc)
##fegrow.fix_receptor("7t79-H-prep.pdb", "rec_final.pdb")

# load back into prody
##rec_final = prody.parsePDB("rec_final.pdb")

#!grep "ATOM" ../structures/7t79-H.pdb > rec_final.pdb
#cs.add_protein(rec_5R83_path)
cs.add_protein('rec_final.pdb')
# Out:
# @> 9116 atoms and 1 coordinate set(s) were parsed in 0.11s.

# %%
# load 50k Smiles
#smiles = pd.read_csv('csv/arthor-hits-2024Mar26-0918.csv',
#                     names=["Smiles", "??", "db"],
#                     index_col=0).Smiles

#smiles = pd.read_csv('smiles.csv').Smiles.to_list()


# take all 20000
#smiles = smiles.apply(lambda r: r.split()[0])
smiles = mols[0:]

# here we add Smiles which should already have been matched
# to the scaffold (rdkit Mol.HasSubstructureMatch)
#cs.add_smiles(smiles.to_list(), protonate=True)
cs.add_smiles(smiles, protonate=True)
cs
# Out:
# Failed to patch pandas - unable to change molecule rendering
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Smiles</th>
#       <th>score</th>
#       <th>h</th>
#       <th>Training</th>
#       <th>Success</th>
#       <th>enamine_searched</th>
#       <th>enamine_id</th>
#       <th>2D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>O=C1c2c(c(c(Cl)c(c2[C@@]2(C(N1C(c1nnc(o1)[H])(...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f5230&gt;</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C(Oc1c(c(c(N(C(c2c(c(c(c(Cl)c2[H])[H])[H])[H])...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f51c0&gt;</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>C(N(C(=O)C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f5310&gt;</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>O=C1c2c(c(c(Cl)c(c2[C@@]2(C(N1C(c1c(c(nnc1[H])...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f52a0&gt;</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C([C@]1(c2c(c(sc2C(C(N1C(=O)C(c1c(nc(c2c(c(c(c...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f53f0&gt;</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>92</th>
#       <td>O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f7990&gt;</td>
#     </tr>
#     <tr>
#       <th>93</th>
#       <td>C([N+](C(C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f7a00&gt;</td>
#     </tr>
#     <tr>
#       <th>94</th>
#       <td>C(C(C(=O)[N@@+]1(C(C(C(c2c(N(C(c3c(c(c(c(Cl)c3...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f7a70&gt;</td>
#     </tr>
#     <tr>
#       <th>95</th>
#       <td>C(N(C(=O)C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f7ae0&gt;</td>
#     </tr>
#     <tr>
#       <th>96</th>
#       <td>O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f0a604f7b50&gt;</td>
#     </tr>
#   </tbody>
# </table>
# <p>97 rows × 8 columns</p>
# </div>

# %%
cs.evaluate(num_conf=500, gnina_gpu=True, penalty=0.0, al_ignore_penalty=False)
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Generated 63 conformers.
# Removed 46 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/17 [00:00<?, ?it/s][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:   6%|█▎                    | 1/17 [00:04<01:10,  4.43s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  18%|███▉                  | 3/17 [00:11<00:52,  3.77s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:  24%|█████▏                | 4/17 [00:14<00:47,  3.69s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Generated 48 conformers.
# Removed 23 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:  29%|██████▍               | 5/17 [00:21<00:58,  4.86s/it][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:   4%|▉                     | 1/25 [00:04<01:51,  4.67s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:   8%|█▊                    | 2/25 [00:07<01:19,  3.47s/it]
# Generated 55 conformers.
# Removed 38 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/17 [00:00<?, ?it/s]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# [W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:   0%|                             | 0/147 [00:00<?, ?it/s]
# Generated 334 conformers.
# Removed 187 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# [W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:   2%|▍                    | 3/147 [00:19<15:40,  6.53s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  41%|█████████             | 7/17 [00:29<00:41,  4.13s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  47%|██████████▎           | 8/17 [00:34<00:39,  4.43s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:
/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  68%|██████████████▎      | 28/41 [03:31<01:20,  6.22s/it]
# Generated 369 conformers.
# Removed 337 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|███████████████████████| 8/8 [03:00<00:00, 22.60s/it]
# Optimising conformer: 100%|█████████████████████| 24/24 [03:28<00:00,  8.69s/it]
# Optimising conformer:   0%|                              | 0/13 [00:00<?, ?it/s]
# Generated 93 conformers.
# Removed 80 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|█████████████████████| 18/18 [03:12<00:00, 10.70s/it]
# Optimising conformer: 100%|█████████████████████| 16/16 [02:00<00:00,  7.52s/it]
# Optimising conformer: 100%|█████████████████████| 41/41 [04:42<00:00,  6.90s/it]
# Optimising conformer: 100%|█████████████████████| 38/38 [08:24<00:00, 13.28s/it]
# Optimising conformer: 100%|█████████████████████| 69/69 [05:15<00:00,  4.57s/it]
# Optimising conformer:  47%|█████████▊           | 15/32 [01:21<01:06,  3.91s/it]
# Generated 65 conformers.
# Removed 54 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/28 [00:00<?, ?it/s]
# Generated 336 conformers.
# Removed 308 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|█████████████████████| 13/13 [00:50<00:00,  3.86s/it]
# Optimising conformer:  75%|███████████████▊     | 24/32 [02:08<00:40,  5.05s/it]
# Generated 413 conformers.
# Removed 354 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|█████████████████████| 11/11 [00:52<00:00,  4.74s/it]
# Optimising conformer:  36%|███████▌             | 10/28 [00:46<01:19,  4.42s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer: 100%|█████████████████████| 32/32 [02:29<00:00,  4.68s/it]
# Optimising conformer:  46%|█████████▊           | 13/28 [00:57<00:59,  3.93s/it]
# Generated 298 conformers.
# Removed 267 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|█████████████████████| 28/28 [01:55<00:00,  4.14s/it]
# Optimising conformer:  48%|██████████▏          | 15/31 [00:59<00:58,  3.64s/it]
# Generated 196 conformers.
# Removed 180 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:  94%|███████████████████▋ | 15/16 [00:55<00:02,  2.80s/it]
# Generated 296 conformers.
# Removed 269 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|█████████████████████| 16/16 [00:58<00:00,  3.63s/it]
# Optimising conformer: 100%|█████████████████████| 31/31 [02:10<00:00,  4.20s/it]
# Optimising conformer:  49%|██████████▎          | 29/59 [02:57<03:12,  6.43s/it]
# Generated 254 conformers.
# Removed 227 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer: 100%|█████████████████████| 27/27 [01:24<00:00,  3.15s/it]
# Optimising conformer: 100%|█████████████████████| 27/27 [02:03<00:00,  4.59s/it]
# Optimising conformer: 100%|█████████████████████| 59/59 [05:35<00:00,  5.68s/it]
#                                                Smiles  \
# 0   O=C1c2c(c(c(Cl)c(c2[C@@]2(C(N1C(c1nnc(o1)[H])(...
# 1   C(Oc1c(c(c(N(C(c2c(c(c(c(Cl)c2[H])[H])[H])[H])...
# 2   C(N(C(=O)C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...
# 3   O=C1c2c(c(c(Cl)c(c2[C@@]2(C(N1C(c1c(c(nnc1[H])...
# 4   C([C@]1(c2c(c(sc2C(C(N1C(=O)C(c1c(nc(c2c(c(c(c...
# ..                                                ...
# 92  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
# 93  C([N+](C(C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...
# 94  C(C(C(=O)[N@@+]1(C(C(C(c2c(N(C(c3c(c(c(c(Cl)c3...
# 95  C(N(C(=O)C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...
# 96  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
#
#                                                Mol  score     h  Training  \
# 0   <fegrow.package.RMol object at 0x7f0a1c4a2a70>  6.694  <NA>      True
# 1   <fegrow.package.RMol object at 0x7f09fc552b60>  6.063  <NA>      True
# 2   <fegrow.package.RMol object at 0x7f09fc5505e0>  6.349  <NA>      True
# 3   <fegrow.package.RMol object at 0x7f0b3e428950>  6.609  <NA>      True
# 4   <fegrow.package.RMol object at 0x7f0a3c25e390>  5.406  <NA>      True
# ..                                             ...    ...   ...       ...
# 92  <fegrow.package.RMol object at 0x7f0a1c4a2e30>  5.757  <NA>      True
# 93  <fegrow.package.RMol object at 0x7f09bc39ef70>  5.922  <NA>      True
# 94  <fegrow.package.RMol object at 0x7f0a6063c040>  6.491  <NA>      True
# 95  <fegrow.package.RMol object at 0x7f0a6061f240>  6.572  <NA>      True
# 96  <fegrow.package.RMol object at 0x7f0b3e1cd940>  5.073  <NA>      True
#
#    Success  enamine_searched enamine_id
# 0     True             False        NaN
# 1     True             False        NaN
# 2     True             False        NaN
# 3     True             False        NaN
# 4     True             False        NaN
# ..     ...               ...        ...
# 92    True             False        NaN
# 93    True             False        NaN
# 94    True             False        NaN
# 95    True             False        NaN
# 96    True             False        NaN
#
# [97 rows x 8 columns]

# %%
cs.df
# Out:
#                                                Smiles  \
# 0   O=C1c2c(c(c(Cl)c(c2[C@@]2(C(N1C(c1nnc(o1)[H])(...
# 1   C(Oc1c(c(c(N(C(c2c(c(c(c(Cl)c2[H])[H])[H])[H])...
# 2   C(N(C(=O)C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...
# 3   O=C1c2c(c(c(Cl)c(c2[C@@]2(C(N1C(c1c(c(nnc1[H])...
# 4   C([C@]1(c2c(c(sc2C(C(N1C(=O)C(c1c(nc(c2c(c(c(c...
# ..                                                ...
# 92  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
# 93  C([N+](C(C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...
# 94  C(C(C(=O)[N@@+]1(C(C(C(c2c(N(C(c3c(c(c(c(Cl)c3...
# 95  C(N(C(=O)C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(c(c(...
# 96  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
#
#                                                Mol  score     h  Training  \
# 0   <fegrow.package.RMol object at 0x7f0a1c4a2a70>  6.694  <NA>      True
# 1   <fegrow.package.RMol object at 0x7f09fc552b60>  6.063  <NA>      True
# 2   <fegrow.package.RMol object at 0x7f09fc5505e0>  6.349  <NA>      True
# 3   <fegrow.package.RMol object at 0x7f0b3e428950>  6.609  <NA>      True
# 4   <fegrow.package.RMol object at 0x7f0a3c25e390>  5.406  <NA>      True
# ..                                             ...    ...   ...       ...
# 92  <fegrow.package.RMol object at 0x7f0a1c4a2e30>  5.757  <NA>      True
# 93  <fegrow.package.RMol object at 0x7f09bc39ef70>  5.922  <NA>      True
# 94  <fegrow.package.RMol object at 0x7f0a6063c040>  6.491  <NA>      True
# 95  <fegrow.package.RMol object at 0x7f0a6061f240>  6.572  <NA>      True
# 96  <fegrow.package.RMol object at 0x7f0b3e1cd940>  5.073  <NA>      True
#
#    Success  enamine_searched enamine_id
# 0     True             False        NaN
# 1     True             False        NaN
# 2     True             False        NaN
# 3     True             False        NaN
# 4     True             False        NaN
# ..     ...               ...        ...
# 92    True             False        NaN
# 93    True             False        NaN
# 94    True             False        NaN
# 95    True             False        NaN
# 96    True             False        NaN
#
# [97 rows x 8 columns]

# %%
cs.to_sdf("cs_optimised_molecules.sdf")

# %%
for i in range (len(cs)):
    try:
        cs[i].to_file("best_conformers_{0}.pdb".format(i))
    except AttributeError:
        print("No conformer for molecule", i)
# Out:
# No conformer for molecule 78

# %%
cs.df.to_csv('MERS-out.csv', index=True)
