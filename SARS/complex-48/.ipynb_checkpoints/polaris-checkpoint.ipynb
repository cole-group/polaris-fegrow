# %% [markdown]
# # FEgrow: An Open-Source Molecular Builder and Free Energy Preparation Workflow
#
# **Authors: Mateusz K Bieniek, Ben Cree, Rachael Pirie, Joshua T. Horton, Natalie J. Tatum, Daniel J. Cole**

# %% [markdown]
# ## Overview
#
# Building and scoring molecules can be further streamlined by employing our established protocol. Here we show how to quickly build a library and score the entire library.

# %%
import pandas as pd
import prody
from rdkit import Chem

import fegrow
from fegrow import ChemSpace

from fegrow.testing import core_5R83_path, rec_5R83_path, data_5R83_path
# Out:
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tmp/ipykernel_636494/1015952767.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was too old on your system - pyarrow 10.0.1 is the current minimum supported version as of this release.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality

# %% [markdown]
# # Prepare the ligand template

# %%
#!grep "XEY" 7l10.pdb > in.pdb
# !obabel -ipdb new-core.pdb -O in-H.sdf -p 7
# Out:
# 1 molecule converted

# %%
#scaffold = Chem.SDMolSupplier(core_5R83_path)[0]
scaffold = Chem.SDMolSupplier('in-H.sdf')[0]

# %%
toview = fegrow.RMol(scaffold)
toview.rep2D(idx=True, size=(500, 500))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %%
with open('smiles-test-SARS.txt') as f:
    mols = f.read().splitlines()

# %%
mols[0]
# Out:
# 'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2CNc2ccncn2)c2cc(Cl)ccc2C1=O'

# %%
#mols = ['C1(OCCC)=CC=CN=C1',
#        'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2CNc2ccncn2)c2cc(Cl)ccc2C1=O',
#        'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2CNc2cnn(C)c2)c2cc(Cl)ccc2C1=O',
#        'Cc1cnc(CN2C[C@@]3(C(=O)N(c4cncc5ccccc45)C[C@@H]3C)c3cc(F)ccc3C2=O)cn1',
#        'CNC(=O)CN1C[C@@]2(C(=O)N(c3cncc4ccccc34)C[C@@H]2COC(C)C)c2cc(Cl)ccc2C1=O',
#        'C[C@H]1CN(c2cncc3ccccc23)C(=O)[C@@]12CN(Cc1nccn1C)C(=O)c1ccc(F)cc12'
#       ]

# %%
Chem.MolFromSmiles(mols[22])

# %%
pattern = scaffold

for i in range(len(mols)):
    mol = Chem.MolFromSmiles(mols[i])
    if mol.HasSubstructMatch(pattern) == False:
        print(i, mols[i])
# Out:
# 33 C[C@H](NC(=O)COS(N)(=O)=O)c1cc(Cl)cc(-c2ccc(S(N)(=O)=O)cc2)c1
# 94 CNS(=O)(=O)OCC(=O)N[C@@H](C)c1cc(Cl)cc(-c2ccc(S(N)(=O)=O)cc2)c1

# %% [markdown]
# As we are using already prepared Smiles that have the scaffold as a substructure, it is not needed to set any growing vector.

# %%
from dask.distributed import LocalCluster
lc = LocalCluster(processes=True, n_workers=None, threads_per_worker=1)
# Out:
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 37795 instead
#   warnings.warn(
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# 2025-03-04 10:43:35,858 - distributed.nanny - WARNING - Restarting worker

# %%
# create the chemical space
cs = ChemSpace(dask_cluster=lc)
cs
# Out:
# Failed to patch pandas - unable to change molecule rendering
# Dask can be watched on http://127.0.0.1:37795/status
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Smiles</th>
#       <th>score</th>
#       <th>h</th>
#       <th>Training</th>
#       <th>Success</th>
#       <th>enamine_searched</th>
#       <th>enamine_id</th>
#       <th>2D</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>
# </div>

# %%
#cs._dask_cluster

# %%
# we're not growing the scaffold, we're superimposing bigger molecules on it
cs.add_scaffold(scaffold)
# Out:
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/fegrow/package.py:799: UserWarning: The template does not have an attachement (Atoms with index 0, or in case of Smiles the * character. )
#   warnings.warn("The template does not have an attachement (Atoms with index 0, "

# %%
# get the protein-ligand complex structure
#!wget -nc https://files.rcsb.org/download/3vf6.pdb

# load the complex with the ligand
sys = prody.parsePDB('complex-48-aligned.pdb')

# remove any unwanted molecules
rec = sys.select('not (nucleic or hetatm or water)')

# save the processed protein
prody.writePDB('rec.pdb', rec)

# fix the receptor file (missing residues, protonation, etc)
fegrow.fix_receptor("rec.pdb", "rec_final.pdb")

# load back into prody
#rec_final = prody.parsePDB("rec_final.pdb")
#rec_final = prody.parsePDB("out.pdb")

# fix the receptor file (missing residues, protonation, etc)
##fegrow.fix_receptor("7t79-H-prep.pdb", "rec_final.pdb")

# load back into prody
##rec_final = prody.parsePDB("rec_final.pdb")

#!grep "ATOM" ../structures/7t79-H.pdb > rec_final.pdb
#cs.add_protein(rec_5R83_path)
cs.add_protein('rec_final.pdb')
# Out:
# @> 9304 atoms and 1 coordinate set(s) were parsed in 0.10s.

# %%
smiles = []
list_of_fails = [11, 18, 22, 26, 29, 35, 42, 60, 68, 93]

for i in list_of_fails:
    smiles.append(mols[i])

# %%
# load 50k Smiles
#smiles = pd.read_csv('csv/arthor-hits-2024Mar26-0918.csv',
#                     names=["Smiles", "??", "db"],
#                     index_col=0).Smiles

#smiles = pd.read_csv('smiles.csv').Smiles.to_list()


# take all 20000
#smiles = smiles.apply(lambda r: r.split()[0])
#smiles = mols[0:]

# here we add Smiles which should already have been matched
# to the scaffold (rdkit Mol.HasSubstructureMatch)
#cs.add_smiles(smiles.to_list(), protonate=True)
cs.add_smiles(smiles, protonate=True)
cs
# Out:
# Failed to patch pandas - unable to change molecule rendering
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Smiles</th>
#       <th>score</th>
#       <th>h</th>
#       <th>Training</th>
#       <th>Success</th>
#       <th>enamine_searched</th>
#       <th>enamine_id</th>
#       <th>2D</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>C(N1C(=O)N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[H...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119380&gt;</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119310&gt;</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>O=C1N([C@@]2(C(C(Oc3c(c(nc(c23)[H])[H])[H])([H...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119460&gt;</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c1193f0&gt;</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119540&gt;</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c1194d0&gt;</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>C(n1nc(c2c(nc(c(N(C(=O)[C@@]3(C(N(S(=O)(=O)c4c...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119620&gt;</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>C(C(n1nc(c(c1C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c1195b0&gt;</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119770&gt;</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>C(C(n1nc(c(c1C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(...</td>
#       <td>&lt;NA&gt;</td>
#       <td>&lt;NA&gt;</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>&lt;rdkit.Chem.rdchem.Mol object at 0x7f314c119690&gt;</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
cs.evaluate(num_conf=500, gnina_gpu=True, penalty=0.0, al_ignore_penalty=False)
# Out:
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# Failed to find the pandas get_adjustment() function to patch
# Failed to patch pandas - PandasTools will have limited functionality
# 2025-03-04 10:39:25,917 - distributed.worker - WARNING - Compute Failed
# Key:       _evaluate_atomic-f5f58330-a592-476a-9c0e-89fe30c5572c
# Function:  execute_task
# args:      ((<function apply at 0x7fa32fa427a0>, <function _evaluate_atomic at 0x7fa230ff3130>, [<rdkit.Chem.rdchem.Mol object at 0x7fa3076dbb00>, 'O=C1N([C@@]2(C(C(Oc3c(c(nc(c23)[H])[H])[H])([H])[H])([H])[H])C(=O)N1c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H])[H])[H]', 'rec_final.pdb'], (<class 'dict'>, [['h', None], ['num_conf', 500], ['minimum_conf_rms', 0.5], ['scoring_function', None], ['gnina_gpu', True]])))
# kwargs:    {}
# Exception: "Exception('No Conformers')"
#
# 2025-03-04 10:39:26,939 - distributed.worker - WARNING - Compute Failed
# Key:       _evaluate_atomic-7ca2d842-094b-4b0d-b68e-b233b3fd4a94
# Function:  execute_task
# args:      ((<function apply at 0x7f401d1127a0>, <function _evaluate_atomic at 0x7f3f1e36beb0>, [<rdkit.Chem.rdchem.Mol object at 0x7f3f1e375f80>, 'C(n1nc(c2c(nc(c(N(C(=O)[C@@]3(C(N(S(=O)(=O)c4c(c(c(Cl)c(c34)[H])[H])[H])[H])([H])[H])[H])[H])c12)[H])[H])[H])([H])([H])[H]', 'rec_final.pdb'], (<class 'dict'>, [['h', None], ['num_conf', 500], ['minimum_conf_rms', 0.5], ['scoring_function', None], ['gnina_gpu', True]])))
# kwargs:    {}
# Exception: "Exception('No Conformers')"
#
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Generated 271 conformers.
# Removed 150 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                             | 0/121 [00:00<?, ?it/s][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:   7%|█▍                   | 8/121 [00:13<03:11,  1.69s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:   8%|█▋                  | 10/121 [00:17<03:12,  1.73s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  12%|██▍                 | 15/121 [00:26<03:04,  1.74s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  31%|██████              | 37/121 [01:11<02:49,  2.02s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer:  51%|██████████▏         | 62/121 [01:49<01:34,  1.59s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:  52%|██████████▍         | 63/121 [01:54<02:26,  2.53s/it]
# Generated 66 conformers.
# Removed 50 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/16 [00:00<?, ?it/s][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:  53%|██████████▌         | 64/121 [01:56<02:29,  2.62s/it]
# Generated 66 conformers.
# Removed 50 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/16 [00:00<?, ?it/s][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:  54%|██████████▋         | 65/121 [01:58<02:03,  2.20s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:   6%|█▍                    | 1/16 [00:04<01:00,  4.03s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Generated 189 conformers.
# Removed 147 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:  12%|██▊                   | 2/16 [00:06<00:39,  2.83s/it][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer: 100%|█████████████████████| 16/16 [00:47<00:00,  2.99s/it]
# Optimising conformer: 100%|█████████████████████| 16/16 [00:48<00:00,  3.01s/it]
# Optimising conformer:  77%|███████████████▎    | 93/121 [02:54<01:02,  2.24s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:  79%|███████████████▊    | 96/121 [02:58<00:40,  1.63s/it]
# Generated 66 conformers.
# Removed 52 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:  33%|███████              | 14/42 [00:56<01:38,  3.53s/it][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer:  88%|████████████████▋  | 106/121 [03:16<00:22,  1.50s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:  88%|████████████████▊  | 107/121 [03:18<00:21,  1.50s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Optimising conformer:  50%|███████████           | 7/14 [00:22<00:29,  4.19s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Generated 145 conformers.
# Removed 123 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:  91%|█████████████████▎ | 110/121 [03:22<00:17,  1.63s/it][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer: 100%|███████████████████| 121/121 [03:42<00:00,  1.84s/it]
# Optimising conformer: 100%|█████████████████████| 14/14 [00:44<00:00,  3.15s/it]
# Optimising conformer:  64%|█████████████▎       | 14/22 [00:50<00:23,  2.94s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Generated 365 conformers.
# Removed 330 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/35 [00:00<?, ?it/s][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer: 100%|█████████████████████| 22/22 [02:06<00:00,  5.74s/it]
# Optimising conformer:  66%|█████████████▊       | 23/35 [01:30<00:42,  3.55s/it]/tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/parmed/structure.py:1799: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   coords = np.array(value, dtype=np.float64, copy=False, subok=True)
# Optimising conformer: 100%|█████████████████████| 35/35 [02:37<00:00,  4.51s/it]
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/__init__.py:55: UserWarning: Dependency not satisfied, torchani.ase will not be available
#   warnings.warn("Dependency not satisfied, torchani.ase will not be available")
# Warning: importing 'simtk.openmm' is deprecated.  Import 'openmm' instead.
# Generated 10 conformers.
# Removed 10 conformers.
# Warning: no conformers so cannot optimise_in_receptor. Ignoring.
# Generated 145 conformers.
# Removed 123 conformers.
# using ani2x
# /tank/home/ndc104/anaconda3/envs/fegrowcs/lib/python3.10/site-packages/torchani/resources/
# failed to equip `nnpops` with error: No module named 'NNPOps'
# Optimising conformer:   0%|                              | 0/22 [00:00<?, ?it/s][W BinaryOps.cpp:601] Warning: floor_divide is deprecated, and will be removed in a future version of pytorch. It currently rounds toward 0 (like the 'trunc' function NOT 'floor'). This results in incorrect rounding for negative values.
# To keep the current behavior, use torch.div(a, b, rounding_mode='trunc'), or for actual floor division, use torch.div(a, b, rounding_mode='floor'). (function operator())
# Optimising conformer: 100%|█████████████████████| 42/42 [07:32<00:00, 10.79s/it]
# Optimising conformer: 100%|█████████████████████| 22/22 [02:04<00:00,  5.66s/it]
#                                               Smiles  \
# 0  C(N1C(=O)N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[H...
# 1  C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...
# 2  O=C1N([C@@]2(C(C(Oc3c(c(nc(c23)[H])[H])[H])([H...
# 3  C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...
# 4  C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...
# 5  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
# 6  C(n1nc(c2c(nc(c(N(C(=O)[C@@]3(C(N(S(=O)(=O)c4c...
# 7  C(C(n1nc(c(c1C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(...
# 8  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
# 9  C(C(n1nc(c(c1C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(...
#
#                                                 Mol  score     h  Training  \
# 0    <fegrow.package.RMol object at 0x7f313455d580>  5.453  <NA>      True
# 1    <fegrow.package.RMol object at 0x7f31107b90d0>  6.921  <NA>      True
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f314f1e0ba0>    0.0  <NA>      True
# 3    <fegrow.package.RMol object at 0x7f3134588f40>   7.02  <NA>      True
# 4    <fegrow.package.RMol object at 0x7f30f061dfd0>   7.02  <NA>      True
# 5    <fegrow.package.RMol object at 0x7f313457c400>  5.064  <NA>      True
# 6  <rdkit.Chem.rdchem.Mol object at 0x7f314f112180>    0.0  <NA>      True
# 7    <fegrow.package.RMol object at 0x7f31105c5260>  7.142  <NA>      True
# 8    <fegrow.package.RMol object at 0x7f31107b9440>  6.056  <NA>      True
# 9    <fegrow.package.RMol object at 0x7f3110407a10>  7.142  <NA>      True
#
#   Success  enamine_searched enamine_id
# 0    True             False        NaN
# 1    True             False        NaN
# 2   False             False        NaN
# 3    True             False        NaN
# 4    True             False        NaN
# 5    True             False        NaN
# 6   False             False        NaN
# 7    True             False        NaN
# 8    True             False        NaN
# 9    True             False        NaN

# %%
cs.df
# Out:
#                                               Smiles  \
# 0  C(N1C(=O)N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[H...
# 1  C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...
# 2  O=C1N([C@@]2(C(C(Oc3c(c(nc(c23)[H])[H])[H])([H...
# 3  C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...
# 4  C([C@]1(C(N(c2c(nc(c3c(c(c(c(c23)[H])[H])[H])[...
# 5  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
# 6  C(n1nc(c2c(nc(c(N(C(=O)[C@@]3(C(N(S(=O)(=O)c4c...
# 7  C(C(n1nc(c(c1C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(...
# 8  O=C(C(c1c(nc(c2c(c(c(c(c12)[H])[H])[H])[H])[H]...
# 9  C(C(n1nc(c(c1C(N1C([C@@]2(C(=O)N(c3c(nc(c4c(c(...
#
#                                                 Mol  score     h  Training  \
# 0    <fegrow.package.RMol object at 0x7f313455d580>  5.453  <NA>      True
# 1    <fegrow.package.RMol object at 0x7f31107b90d0>  6.921  <NA>      True
# 2  <rdkit.Chem.rdchem.Mol object at 0x7f314f1e0ba0>    0.0  <NA>      True
# 3    <fegrow.package.RMol object at 0x7f3134588f40>   7.02  <NA>      True
# 4    <fegrow.package.RMol object at 0x7f30f061dfd0>   7.02  <NA>      True
# 5    <fegrow.package.RMol object at 0x7f313457c400>  5.064  <NA>      True
# 6  <rdkit.Chem.rdchem.Mol object at 0x7f314f112180>    0.0  <NA>      True
# 7    <fegrow.package.RMol object at 0x7f31105c5260>  7.142  <NA>      True
# 8    <fegrow.package.RMol object at 0x7f31107b9440>  6.056  <NA>      True
# 9    <fegrow.package.RMol object at 0x7f3110407a10>  7.142  <NA>      True
#
#   Success  enamine_searched enamine_id
# 0    True             False        NaN
# 1    True             False        NaN
# 2   False             False        NaN
# 3    True             False        NaN
# 4    True             False        NaN
# 5    True             False        NaN
# 6   False             False        NaN
# 7    True             False        NaN
# 8    True             False        NaN
# 9    True             False        NaN

# %%
cs.to_sdf("cs_optimised_molecules.sdf")

# %%
for i in range (len(cs)):
    try:
        cs[i].to_file("best_conformers_{0}.pdb".format(list_of_fails[i]))
    except AttributeError:
        print("No conformer for molecule", i)
# Out:
# No conformer for molecule 2
# No conformer for molecule 6

# %%
cs.df.to_csv('SARS-out.csv', index=True)
